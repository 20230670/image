# %% [markdown]
# <a href="https://colab.research.google.com/github/20230670/image/blob/main/image_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pillow

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

img = Image.open('cat.jpg')

img_np = np.array(img)

plt.imshow(img_np)
plt.show()
